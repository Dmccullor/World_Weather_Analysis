# %%
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count +=1
    
    try:
        city_weather = requests.get(city_url).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc})
        
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | geraldton
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | havre-saint-pierre
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | great yarmouth
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | seoul
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | langsa
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | matara
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | samarai
# Processing Record 25 of Set 1 | dalvik
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | kangshan
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | hay river
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | presidencia roque saenz pena
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | lorengau
# Processing Record 38 of Set 1 | nizwa
# Processing Record 39 of Set 1 | posse
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | igrim
# Processing Record 43 of Set 1 | boksitogorsk
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | sinnamary
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | cayenne
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | labuhan
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | celestun
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | mahon
# Processing Record 8 of Set 2 | coos bay
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | maxixe
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | kahului
# Processing Record 14 of Set 2 | banjarmasin
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | sao gabriel da cachoeira
# Processing Record 17 of Set 2 | salinas
# Processing Record 18 of Set 2 | laurel
# Processing Record 19 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | hailar
# Processing Record 23 of Set 2 | rockland
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | yumen
# Processing Record 26 of Set 2 | sfantu gheorghe
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | jepara
# Processing Record 29 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | nizhnevartovsk
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | salto de agua
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | troitsko-pechorsk
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | marsabit
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | atherton
# Processing Record 40 of Set 2 | nantucket
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | tautira
# Processing Record 45 of Set 2 | jiwani
# Processing Record 46 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | charters towers
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | vardo
# Processing Record 6 of Set 3 | chapais
# Processing Record 7 of Set 3 | wenling
# Processing Record 8 of Set 3 | namibe
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | hopkinsville
# Processing Record 12 of Set 3 | kavaratti
# Processing Record 13 of Set 3 | bozoum
# Processing Record 14 of Set 3 | lekoni
# Processing Record 15 of Set 3 | fort nelson
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | hovd
# Processing Record 18 of Set 3 | chinsali
# Processing Record 19 of Set 3 | san juan
# Processing Record 20 of Set 3 | hostotipaquillo
# Processing Record 21 of Set 3 | xining
# Processing Record 22 of Set 3 | chegdomyn
# Processing Record 23 of Set 3 | nizhniy odes
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | anloga
# Processing Record 26 of Set 3 | cap-aux-meules
# Processing Record 27 of Set 3 | iquitos
# Processing Record 28 of Set 3 | ahipara
# Processing Record 29 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 3 | waiuku
# Processing Record 31 of Set 3 | shingu
# Processing Record 32 of Set 3 | kilakarai
# Processing Record 33 of Set 3 | arman
# Processing Record 34 of Set 3 | jumla
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | lianzhou
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | mount gambier
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | san jose
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | toumodi
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | tessalit
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | caramay
# Processing Record 1 of Set 4 | namatanai
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 4 of Set 4 | sol-iletsk
# Processing Record 5 of Set 4 | phan thiet
# Processing Record 6 of Set 4 | los llanos de aridane
# Processing Record 7 of Set 4 | padang
# Processing Record 8 of Set 4 | bairiki
# Processing Record 9 of Set 4 | sao joao evangelista
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | rioja
# Processing Record 12 of Set 4 | hokitika
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | bereznik
# Processing Record 15 of Set 4 | faya
# Processing Record 16 of Set 4 | dickinson
# Processing Record 17 of Set 4 | kirkkonummi
# Processing Record 18 of Set 4 | north bend
# Processing Record 19 of Set 4 | norsup
# Processing Record 20 of Set 4 | port hawkesbury
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | chumikan
# Processing Record 25 of Set 4 | monduli
# Processing Record 26 of Set 4 | rincon
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | oranjemund
# Processing Record 29 of Set 4 | walvis bay
# Processing Record 30 of Set 4 | la asuncion
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | vaini
# Processing Record 33 of Set 4 | marfino
# Processing Record 34 of Set 4 | qaanaaq
# Processing Record 35 of Set 4 | pitkyaranta
# Processing Record 36 of Set 4 | erenhot
# Processing Record 37 of Set 4 | osoyoos
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 4 | wagar
# Processing Record 42 of Set 4 | buala
# Processing Record 43 of Set 4 | limoux
# Processing Record 44 of Set 4 | san quintin
# Processing Record 45 of Set 4 | mudgee
# Processing Record 46 of Set 4 | gotsu
# Processing Record 47 of Set 4 | san mateo del mar
# Processing Record 48 of Set 4 | nemuro
# Processing Record 49 of Set 4 | ust-kuyga
# Processing Record 50 of Set 4 | qaqortoq
# Processing Record 1 of Set 5 | half moon bay
# Processing Record 2 of Set 5 | nanortalik
# Processing Record 3 of Set 5 | dhidhdhoo
# Processing Record 4 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 5 | champagnole
# Processing Record 6 of Set 5 | port moresby
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | vung tau
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | andenes
# Processing Record 11 of Set 5 | greeley
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 5 | mount isa
# Processing Record 16 of Set 5 | cockburn town
# Processing Record 17 of Set 5 | puerto ayacucho
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | kudahuvadhoo
# Processing Record 20 of Set 5 | acapulco
# Processing Record 21 of Set 5 | skibbereen
# Processing Record 22 of Set 5 | lewiston
# Processing Record 23 of Set 5 | abu samrah
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | kieta
# Processing Record 28 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 29 of Set 5 | hurghada
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | semporna
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | launceston
# Processing Record 34 of Set 5 | yashkul
# Processing Record 35 of Set 5 | nelson bay
# Processing Record 36 of Set 5 | sambava
# Processing Record 37 of Set 5 | kenai
# Processing Record 38 of Set 5 | borogontsy
# Processing Record 39 of Set 5 | takoradi
# Processing Record 40 of Set 5 | huangmei
# Processing Record 41 of Set 5 | tansen
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | caucaia
# Processing Record 44 of Set 5 | mahebourg
# Processing Record 45 of Set 5 | teberda
# Processing Record 46 of Set 5 | robertsport
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | windhoek
# Processing Record 49 of Set 5 | eshowe
# Processing Record 50 of Set 5 | muros
# Processing Record 1 of Set 6 | pahrump
# Processing Record 2 of Set 6 | meulaboh
# Processing Record 3 of Set 6 | grand gaube
# Processing Record 4 of Set 6 | pacific grove
# Processing Record 5 of Set 6 | alta floresta
# Processing Record 6 of Set 6 | yanam
# Processing Record 7 of Set 6 | araouane
# Processing Record 8 of Set 6 | okhotsk
# Processing Record 9 of Set 6 | mawlaik
# Processing Record 10 of Set 6 | rio gallegos
# Processing Record 11 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 12 of Set 6 | sorland
# Processing Record 13 of Set 6 | saint-philippe
# Processing Record 14 of Set 6 | margate
# Processing Record 15 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 6 | kargopol
# Processing Record 17 of Set 6 | husavik
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | waipawa
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 22 of Set 6 | verkhnevilyuysk
# Processing Record 23 of Set 6 | nouadhibou
# Processing Record 24 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | henties bay
# Processing Record 27 of Set 6 | puting kahoy
# Processing Record 28 of Set 6 | torbay
# Processing Record 29 of Set 6 | nador
# Processing Record 30 of Set 6 | kantang
# Processing Record 31 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 6 | kailua
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | altamont
# Processing Record 35 of Set 6 | rundu
# Processing Record 36 of Set 6 | bethal
# Processing Record 37 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 6 | daosa
# City not found. Skipping...
# Processing Record 39 of Set 6 | den helder
# Processing Record 40 of Set 6 | bulawayo
# Processing Record 41 of Set 6 | bonavista
# Processing Record 42 of Set 6 | balotra
# Processing Record 43 of Set 6 | biak
# Processing Record 44 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | guymon
# Processing Record 46 of Set 6 | simao
# Processing Record 47 of Set 6 | kalasin
# Processing Record 48 of Set 6 | klaksvik
# Processing Record 49 of Set 6 | fort morgan
# Processing Record 50 of Set 6 | parabel
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | ust-omchug
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | zhangye
# Processing Record 5 of Set 7 | kasempa
# Processing Record 6 of Set 7 | havelock
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | powell river
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | sovetskiy
# Processing Record 11 of Set 7 | aljezur
# Processing Record 12 of Set 7 | axim
# Processing Record 13 of Set 7 | ibra
# Processing Record 14 of Set 7 | sedam
# Processing Record 15 of Set 7 | praxedis guerrero
# Processing Record 16 of Set 7 | dongargaon
# Processing Record 17 of Set 7 | filingue
# Processing Record 18 of Set 7 | matagami
# Processing Record 19 of Set 7 | road town
# Processing Record 20 of Set 7 | caala
# Processing Record 21 of Set 7 | japura
# Processing Record 22 of Set 7 | lao cai
# Processing Record 23 of Set 7 | vestmannaeyjar
# Processing Record 24 of Set 7 | aquiraz
# Processing Record 25 of Set 7 | homer
# Processing Record 26 of Set 7 | tilichiki
# Processing Record 27 of Set 7 | bongandanga
# Processing Record 28 of Set 7 | voyvozh
# Processing Record 29 of Set 7 | gossaigaon
# Processing Record 30 of Set 7 | cabedelo
# Processing Record 31 of Set 7 | gander
# Processing Record 32 of Set 7 | opuwo
# Processing Record 33 of Set 7 | kaeo
# Processing Record 34 of Set 7 | hoquiam
# Processing Record 35 of Set 7 | avera
# Processing Record 36 of Set 7 | salym
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | viedma
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | victor harbor
# Processing Record 41 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 7 | santa maria
# Processing Record 43 of Set 7 | sao filipe
# Processing Record 44 of Set 7 | srednekolymsk
# Processing Record 45 of Set 7 | uong bi
# Processing Record 46 of Set 7 | belmonte
# Processing Record 47 of Set 7 | port keats
# Processing Record 48 of Set 7 | tocopilla
# Processing Record 49 of Set 7 | yerbogachen
# Processing Record 50 of Set 7 | rongcheng
# Processing Record 1 of Set 8 | vestmanna
# Processing Record 2 of Set 8 | nuuk
# Processing Record 3 of Set 8 | haines junction
# Processing Record 4 of Set 8 | kaspiysk
# Processing Record 5 of Set 8 | ascope
# Processing Record 6 of Set 8 | kaabong
# Processing Record 7 of Set 8 | anadyr
# Processing Record 8 of Set 8 | bereda
# Processing Record 9 of Set 8 | saint-augustin
# Processing Record 10 of Set 8 | pegnitz
# Processing Record 11 of Set 8 | katsuura
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | kolondieba
# Processing Record 14 of Set 8 | zhangjiakou
# Processing Record 15 of Set 8 | hamilton
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | dunedin
# Processing Record 18 of Set 8 | nadym
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | burica
# City not found. Skipping...
# Processing Record 21 of Set 8 | moranbah
# Processing Record 22 of Set 8 | filadelfia
# Processing Record 23 of Set 8 | san ramon
# Processing Record 24 of Set 8 | ornes
# Processing Record 25 of Set 8 | okha
# Processing Record 26 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 8 | porto novo
# Processing Record 28 of Set 8 | tutoia
# Processing Record 29 of Set 8 | yarmouth
# Processing Record 30 of Set 8 | clyde river
# Processing Record 31 of Set 8 | meadow lake
# Processing Record 32 of Set 8 | bharatpur
# Processing Record 33 of Set 8 | harper
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | port blair
# Processing Record 36 of Set 8 | shimoda
# Processing Record 37 of Set 8 | sokoni
# Processing Record 38 of Set 8 | mao
# Processing Record 39 of Set 8 | port hardy
# Processing Record 40 of Set 8 | kaohsiung
# Processing Record 41 of Set 8 | muhos
# Processing Record 42 of Set 8 | ust-tarka
# Processing Record 43 of Set 8 | balkanabat
# Processing Record 44 of Set 8 | tahta
# Processing Record 45 of Set 8 | el alto
# Processing Record 46 of Set 8 | pachino
# Processing Record 47 of Set 8 | fomboni
# Processing Record 48 of Set 8 | natal
# Processing Record 49 of Set 8 | inongo
# Processing Record 50 of Set 8 | ketchikan
# Processing Record 1 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 2 of Set 9 | airai
# Processing Record 3 of Set 9 | berlevag
# Processing Record 4 of Set 9 | carnarvon
# Processing Record 5 of Set 9 | gunnedah
# Processing Record 6 of Set 9 | zhigalovo
# Processing Record 7 of Set 9 | terrace bay
# Processing Record 8 of Set 9 | oia
# Processing Record 9 of Set 9 | kichera
# Processing Record 10 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 11 of Set 9 | sakakah
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | ola
# Processing Record 14 of Set 9 | waingapu
# Processing Record 15 of Set 9 | elesbao veloso
# Processing Record 16 of Set 9 | sulangan
# Processing Record 17 of Set 9 | fairbanks
# Processing Record 18 of Set 9 | san pedro
# Processing Record 19 of Set 9 | mbala
# Processing Record 20 of Set 9 | haicheng
# Processing Record 21 of Set 9 | astoria
# Processing Record 22 of Set 9 | joensuu
# Processing Record 23 of Set 9 | marathon
# Processing Record 24 of Set 9 | lasa
# Processing Record 25 of Set 9 | pontalina
# Processing Record 26 of Set 9 | dingle
# Processing Record 27 of Set 9 | moose factory
# Processing Record 28 of Set 9 | hervey bay
# Processing Record 29 of Set 9 | san policarpo
# Processing Record 30 of Set 9 | almaznyy
# Processing Record 31 of Set 9 | tecolutla
# Processing Record 32 of Set 9 | ariquemes
# Processing Record 33 of Set 9 | lingao
# Processing Record 34 of Set 9 | leningradskiy
# Processing Record 35 of Set 9 | shenjiamen
# Processing Record 36 of Set 9 | serenje
# Processing Record 37 of Set 9 | mana
# Processing Record 38 of Set 9 | camabatela
# Processing Record 39 of Set 9 | ipilan
# Processing Record 40 of Set 9 | ilulissat
# Processing Record 41 of Set 9 | bay city
# Processing Record 42 of Set 9 | perpignan
# Processing Record 43 of Set 9 | takanabe
# Processing Record 44 of Set 9 | teul
# City not found. Skipping...
# Processing Record 45 of Set 9 | sukumo
# Processing Record 46 of Set 9 | coquimbo
# Processing Record 47 of Set 9 | gorele
# Processing Record 48 of Set 9 | vallenar
# Processing Record 49 of Set 9 | teknaf
# Processing Record 50 of Set 9 | xianyang
# Processing Record 1 of Set 10 | kostomuksha
# Processing Record 2 of Set 10 | saint-francois
# Processing Record 3 of Set 10 | aden
# Processing Record 4 of Set 10 | santa maria del oro
# Processing Record 5 of Set 10 | gravdal
# Processing Record 6 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 10 | dzaoudzi
# Processing Record 9 of Set 10 | lavrentiya
# Processing Record 10 of Set 10 | otacilio costa
# Processing Record 11 of Set 10 | chake chake
# Processing Record 12 of Set 10 | ouallam
# Processing Record 13 of Set 10 | severo-kurilsk
# Processing Record 14 of Set 10 | youhao
# Processing Record 15 of Set 10 | hambantota
# Processing Record 16 of Set 10 | stornoway
# Processing Record 17 of Set 10 | mareeba
# Processing Record 18 of Set 10 | muzhi
# Processing Record 19 of Set 10 | busca
# Processing Record 20 of Set 10 | provideniya
# Processing Record 21 of Set 10 | asyut
# Processing Record 22 of Set 10 | gizo
# Processing Record 23 of Set 10 | makaha
# Processing Record 24 of Set 10 | vilcun
# Processing Record 25 of Set 10 | kaa-khem
# Processing Record 26 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 27 of Set 10 | lindi
# Processing Record 28 of Set 10 | raudeberg
# Processing Record 29 of Set 10 | kabinda
# Processing Record 30 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 31 of Set 10 | vanavara
# Processing Record 32 of Set 10 | usvyaty
# Processing Record 33 of Set 10 | laguna
# Processing Record 34 of Set 10 | namangan
# Processing Record 35 of Set 10 | athmallik
# Processing Record 36 of Set 10 | mananjary
# Processing Record 37 of Set 10 | paulo ramos
# Processing Record 38 of Set 10 | roebourne
# Processing Record 39 of Set 10 | petrovsk
# Processing Record 40 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 10 | pocone
# Processing Record 42 of Set 10 | seymchan
# Processing Record 43 of Set 10 | fremont
# Processing Record 44 of Set 10 | basco
# Processing Record 45 of Set 10 | kuntaur
# Processing Record 46 of Set 10 | baracoa
# Processing Record 47 of Set 10 | caravelas
# Processing Record 48 of Set 10 | sorong
# Processing Record 49 of Set 10 | portneuf
# Processing Record 50 of Set 10 | mendi
# Processing Record 1 of Set 11 | cap malheureux
# Processing Record 2 of Set 11 | jiuquan
# Processing Record 3 of Set 11 | sibolga
# Processing Record 4 of Set 11 | hedaru
# Processing Record 5 of Set 11 | erdenet
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | sitka
# Processing Record 8 of Set 11 | asmara
# Processing Record 9 of Set 11 | aki
# Processing Record 10 of Set 11 | golden
# Processing Record 11 of Set 11 | abatskoye
# Processing Record 12 of Set 11 | porto belo
# Processing Record 13 of Set 11 | kapit
# Processing Record 14 of Set 11 | buraydah
# Processing Record 15 of Set 11 | kaduqli
# Processing Record 16 of Set 11 | praya
# Processing Record 17 of Set 11 | aswan
# Processing Record 18 of Set 11 | xingtai
# Processing Record 19 of Set 11 | disna
# Processing Record 20 of Set 11 | mikhaylovka
# Processing Record 21 of Set 11 | gazanjyk
# Processing Record 22 of Set 11 | sabang
# Processing Record 23 of Set 11 | mtwara
# Processing Record 24 of Set 11 | kokopo
# Processing Record 25 of Set 11 | murgab
# Processing Record 26 of Set 11 | mathbaria
# Processing Record 27 of Set 11 | codrington
# Processing Record 28 of Set 11 | marshall
# Processing Record 29 of Set 11 | toila
# Processing Record 30 of Set 11 | gigmoto
# Processing Record 31 of Set 11 | barentu
# Processing Record 32 of Set 11 | bengkulu
# Processing Record 33 of Set 11 | eureka
# Processing Record 34 of Set 11 | lagoa
# Processing Record 35 of Set 11 | camacha
# Processing Record 36 of Set 11 | liverpool
# Processing Record 37 of Set 11 | zhireken
# Processing Record 38 of Set 11 | pafos
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 11 | taltal
# Processing Record 42 of Set 11 | wajir
# Processing Record 43 of Set 11 | leninskoye
# Processing Record 44 of Set 11 | tikhvin
# Processing Record 45 of Set 11 | jalu
# Processing Record 46 of Set 11 | taunggyi
# Processing Record 47 of Set 11 | kanye
# Processing Record 48 of Set 11 | mayya
# Processing Record 49 of Set 11 | aksarka
# Processing Record 50 of Set 11 | illapel
# Processing Record 1 of Set 12 | chisindia
# Processing Record 2 of Set 12 | topolobampo
# Processing Record 3 of Set 12 | sao joao da barra
# Processing Record 4 of Set 12 | bubaque
# Processing Record 5 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 12 | petatlan
# Processing Record 7 of Set 12 | belyy yar
# Processing Record 8 of Set 12 | senanga
# Processing Record 9 of Set 12 | uzunkopru
# City not found. Skipping...
# Processing Record 10 of Set 12 | terenga
# City not found. Skipping...
# Processing Record 11 of Set 12 | salalah
# Processing Record 12 of Set 12 | peleduy
# Processing Record 13 of Set 12 | vao
# Processing Record 14 of Set 12 | kostroma
# Processing Record 15 of Set 12 | dhuwaran
# Processing Record 16 of Set 12 | touba
# Processing Record 17 of Set 12 | praia da vitoria
# Processing Record 18 of Set 12 | mersin
# Processing Record 19 of Set 12 | abu zabad
# Processing Record 20 of Set 12 | sumenep
# Processing Record 21 of Set 12 | dillon
# Processing Record 22 of Set 12 | ardesen
# Processing Record 23 of Set 12 | bosanska krupa
# Processing Record 24 of Set 12 | marmaron
# City not found. Skipping...
# Processing Record 25 of Set 12 | saint anthony
# Processing Record 26 of Set 12 | sayhat
# Processing Record 27 of Set 12 | labuan
# Processing Record 28 of Set 12 | pahalgam
# Processing Record 29 of Set 12 | rawson
# Processing Record 30 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 12 | chingirlau
# Processing Record 32 of Set 12 | bintulu
# Processing Record 33 of Set 12 | pemangkat
# Processing Record 34 of Set 12 | denpasar
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | imeni babushkina
# Processing Record 37 of Set 12 | west bay
# Processing Record 38 of Set 12 | alta
# Processing Record 39 of Set 12 | taoudenni
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | isangel
# Processing Record 42 of Set 12 | bonfim
# Processing Record 43 of Set 12 | bud
# Processing Record 44 of Set 12 | arequipa
# Processing Record 45 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 12 | phalombe
# Processing Record 47 of Set 12 | tezu
# Processing Record 48 of Set 12 | vero beach
# Processing Record 49 of Set 12 | novikovo
# Processing Record 50 of Set 12 | port-cartier
# Processing Record 1 of Set 13 | gornopravdinsk
# Processing Record 2 of Set 13 | cutzamala
# City not found. Skipping...
# Processing Record 3 of Set 13 | svetlogorsk
# Processing Record 4 of Set 13 | lichfield
# Processing Record 5 of Set 13 | sur
# Processing Record 6 of Set 13 | golakganj
# Processing Record 7 of Set 13 | seminole
# Processing Record 8 of Set 13 | ossora
# Processing Record 9 of Set 13 | mayumba
# Processing Record 10 of Set 13 | kloulklubed
# Processing Record 11 of Set 13 | chicama
# Processing Record 12 of Set 13 | igarka
# Processing Record 13 of Set 13 | itamaraca
# Processing Record 14 of Set 13 | barbacoas
# Processing Record 15 of Set 13 | bajil
# Processing Record 16 of Set 13 | kambove
# Processing Record 17 of Set 13 | seydisehir
# Processing Record 18 of Set 13 | roald
# Processing Record 19 of Set 13 | kozova
# Processing Record 20 of Set 13 | dicabisagan
# Processing Record 21 of Set 13 | joao pinheiro
# Processing Record 22 of Set 13 | chaoyang
# Processing Record 23 of Set 13 | notodden
# Processing Record 24 of Set 13 | heanor
# Processing Record 25 of Set 13 | dwarka
# Processing Record 26 of Set 13 | aguilas
# Processing Record 27 of Set 13 | shush
# Processing Record 28 of Set 13 | karratha
# Processing Record 29 of Set 13 | mayo
# Processing Record 30 of Set 13 | oinacu
# Processing Record 31 of Set 13 | angoche
# Processing Record 32 of Set 13 | general elizardo aquino
# Processing Record 33 of Set 13 | missao velha
# Processing Record 34 of Set 13 | kota tinggi
# Processing Record 35 of Set 13 | providencia
# Processing Record 36 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 13 | lashio
# Processing Record 38 of Set 13 | pontes e lacerda
# Processing Record 39 of Set 13 | srandakan
# Processing Record 40 of Set 13 | birjand
# Processing Record 41 of Set 13 | cabot
# Processing Record 42 of Set 13 | thaton
# Processing Record 43 of Set 13 | nha trang
# Processing Record 44 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 13 | iskateley
# Processing Record 46 of Set 13 | chino valley
# Processing Record 47 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 48 of Set 13 | oulu
# Processing Record 49 of Set 13 | raga
# Processing Record 50 of Set 13 | egvekinot
# Processing Record 1 of Set 14 | jaragua
# Processing Record 2 of Set 14 | wajima
# Processing Record 3 of Set 14 | myitkyina
# Processing Record 4 of Set 14 | iralaya
# Processing Record 5 of Set 14 | vila
# Processing Record 6 of Set 14 | palampur
# Processing Record 7 of Set 14 | chokwe
# Processing Record 8 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | yichun
# Processing Record 10 of Set 14 | hare bay
# Processing Record 11 of Set 14 | yamada
# Processing Record 12 of Set 14 | bathsheba
# Processing Record 13 of Set 14 | monte patria
# Processing Record 14 of Set 14 | westport
# Processing Record 15 of Set 14 | mariental
# Processing Record 16 of Set 14 | pundaguitan
# Processing Record 17 of Set 14 | dabakala
# Processing Record 18 of Set 14 | majene
# Processing Record 19 of Set 14 | gushikawa
# Processing Record 20 of Set 14 | katobu
# Processing Record 21 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 22 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 14 | sunland park
# Processing Record 24 of Set 14 | kargil
# Processing Record 25 of Set 14 | upata
# Processing Record 26 of Set 14 | pecos
# Processing Record 27 of Set 14 | oistins
# Processing Record 28 of Set 14 | gidam
# Processing Record 29 of Set 14 | leshukonskoye
# Processing Record 30 of Set 14 | morondava
# Processing Record 31 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 14 | necochea
# Processing Record 33 of Set 14 | otukpo
# Processing Record 34 of Set 14 | honiara
# Processing Record 35 of Set 14 | mandalgovi
# Processing Record 36 of Set 14 | costa rica
# Processing Record 37 of Set 14 | lipin bor
# Processing Record 38 of Set 14 | wilmington island
# Processing Record 39 of Set 14 | bagdarin
# Processing Record 40 of Set 14 | chernyshkovskiy
# Processing Record 41 of Set 14 | saint john
# Processing Record 42 of Set 14 | oranmore
# Processing Record 43 of Set 14 | caloundra
# Processing Record 44 of Set 14 | kaifeng
# Processing Record 45 of Set 14 | rurrenabaque
# Processing Record 46 of Set 14 | ulladulla
# Processing Record 47 of Set 14 | rock sound
# Processing Record 48 of Set 14 | surgut
# Processing Record 49 of Set 14 | can tho
# Processing Record 50 of Set 14 | korla
# Processing Record 1 of Set 15 | yatou
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | hammerfest
# Processing Record 4 of Set 15 | yamethin
# Processing Record 5 of Set 15 | bilma
# Processing Record 6 of Set 15 | sola
# Processing Record 7 of Set 15 | ikungi
# Processing Record 8 of Set 15 | jacqueville
# Processing Record 9 of Set 15 | hami
# Processing Record 10 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 11 of Set 15 | finschhafen
# Processing Record 12 of Set 15 | bilibino
# Processing Record 13 of Set 15 | itoman
# Processing Record 14 of Set 15 | fare
# Processing Record 15 of Set 15 | puerto carreno
# Processing Record 16 of Set 15 | kanel
# Processing Record 17 of Set 15 | ormara
# Processing Record 18 of Set 15 | long xuyen
# Processing Record 19 of Set 15 | rodnikovskaya
# Processing Record 20 of Set 15 | paso de los toros
# Processing Record 21 of Set 15 | jardim
# Processing Record 22 of Set 15 | port augusta
# Processing Record 23 of Set 15 | gallup
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Albany      US  42.6001  -73.9662     72.30        69
# 1           Geraldton      AU -28.7667  114.6000     66.13        77
# 2           Esperance      AU -33.8667  121.9000     58.84        63
# 3          Georgetown      MY   5.4112  100.3354     87.73        79
# 4         Pangnirtung      CA  66.1451  -65.7125     47.59        90
# 5           Cape Town      ZA -33.9258   18.4232     51.12        66
# 6  Havre-Saint-Pierre      CA  50.2334  -63.5986     52.16        87
# 7             Mataura      NZ -46.1927  168.8643     50.49        80
# 8        Longyearbyen      SJ  78.2186   15.6401     42.64        81
# 9              Atuona      PF  -9.8000 -139.0333     78.42        70
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.84     overcast clouds
# 1          90        6.91     overcast clouds
# 2          98       20.33     overcast clouds
# 3          20        1.01          few clouds
# 4         100       13.02       moderate rain
# 5         100        3.44                mist
# 6           1        0.00           clear sky
# 7          94        3.56          light rain
# 8          75       13.80       broken clouds
# 9          15       17.85          few clouds

# %%
output_data_file = "weatherpy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
